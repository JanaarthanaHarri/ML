# %% [markdown]
# Use the dataset: https://www.tensorflow.org/datasets/catalog/citrus_leaves

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import keras

import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator as IDG
from sklearn.model_selection import train_test_split

# %% [markdown]
# Split it into a training set, and a test set and Preprocess data

# %%
# Using Image data generator for data augmentation and to save memory.
idg_train = IDG(
    rescale=1./ 255,
    rotation_range=180,
    zoom_range=0.3,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.25)

idg_test = IDG(rescale=1./ 255)

ds_train=idg_train.flow_from_directory(r'C:\Users\janah\Desktop\ML - 257\Assignments\HW11\Citrus\train',batch_size=32,shuffle=True,subset='training')
ds_valid=idg_train.flow_from_directory(r'C:\Users\janah\Desktop\ML - 257\Assignments\HW11\Citrus\train',batch_size=8,shuffle=True,subset='validation')
ds_test=idg_test.flow_from_directory(r'C:\Users\janah\Desktop\ML - 257\Assignments\HW11\Citrus\test',batch_size=1,shuffle=True)
# Out:
# Found 358 images belonging to 4 classes.
# Found 117 images belonging to 4 classes.
# Found 121 images belonging to 4 classes.

# %% [markdown]
# Build CNN Model and comment on the results

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers as rg
from tensorflow.keras import initializers as it

model = tf.keras.Sequential([
    layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 3),padding='same'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(32, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(4, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_7 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 512)               2097664
#
#  dense_5 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,197,156
# Trainable params: 2,197,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Used Adam as optimizer, Categorical Cross Entropy as Loss and Hyper Parameters - Learning Rate - 0.0001

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy','Precision','Recall']
)

history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=35
 )
# Out:
# Epoch 1/35
# 12/12 [==============================] - 35s 3s/step - loss: 1.3423 - accuracy: 0.3240 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3018 - val_accuracy: 0.3419 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.3047 - accuracy: 0.3966 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2914 - val_accuracy: 0.2991 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.2766 - accuracy: 0.4050 - precision: 1.0000 - recall: 0.0028 - val_loss: 1.2763 - val_accuracy: 0.3504 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.2466 - accuracy: 0.3994 - precision: 0.8333 - recall: 0.0140 - val_loss: 1.2204 - val_accuracy: 0.4188 - val_precision: 1.0000 - val_recall: 0.0085
# Epoch 5/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.1814 - accuracy: 0.4497 - precision: 0.8824 - recall: 0.1257 - val_loss: 1.2301 - val_accuracy: 0.4188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.1655 - accuracy: 0.4441 - precision: 0.7143 - recall: 0.0978 - val_loss: 1.1588 - val_accuracy: 0.4530 - val_precision: 0.6667 - val_recall: 0.1709
# Epoch 7/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.0492 - accuracy: 0.5056 - precision: 0.7816 - recall: 0.1899 - val_loss: 1.1305 - val_accuracy: 0.5726 - val_precision: 0.5938 - val_recall: 0.1624
# Epoch 8/35
# 12/12 [==============================] - 28s 2s/step - loss: 1.0342 - accuracy: 0.5251 - precision: 0.7350 - recall: 0.2402 - val_loss: 1.0495 - val_accuracy: 0.5385 - val_precision: 0.7353 - val_recall: 0.2137
# Epoch 9/35
# 12/12 [==============================] - 28s 2s/step - loss: 0.9706 - accuracy: 0.5559 - precision: 0.6993 - recall: 0.2989 - val_loss: 1.0306 - val_accuracy: 0.5556 - val_precision: 0.8000 - val_recall: 0.2393
# Epoch 10/35
# 12/12 [==============================] - 28s 2s/step - loss: 0.9242 - accuracy: 0.5363 - precision: 0.6923 - recall: 0.3268 - val_loss: 1.0927 - val_accuracy: 0.4017 - val_precision: 0.5254 - val_recall: 0.2650
# Epoch 11/35
# 12/12 [==============================] - 29s 2s/step - loss: 0.9272 - accuracy: 0.5447 - precision: 0.6634 - recall: 0.3799 - val_loss: 1.0168 - val_accuracy: 0.5214 - val_precision: 0.6545 - val_recall: 0.3077
# Epoch 12/35
# 12/12 [==============================] - 27s 2s/step - loss: 0.8828 - accuracy: 0.5782 - precision: 0.6983 - recall: 0.3492 - val_loss: 1.0219 - val_accuracy: 0.4444 - val_precision: 0.6957 - val_recall: 0.2735
# Epoch 13/35
# 12/12 [==============================] - 19s 2s/step - loss: 0.9271 - accuracy: 0.5642 - precision: 0.6498 - recall: 0.3939 - val_loss: 1.1983 - val_accuracy: 0.3846 - val_precision: 0.4868 - val_recall: 0.3162
# Epoch 14/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.9278 - accuracy: 0.5894 - precision: 0.6573 - recall: 0.3911 - val_loss: 1.1544 - val_accuracy: 0.3846 - val_precision: 0.4615 - val_recall: 0.2564
# Epoch 15/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.8418 - accuracy: 0.6229 - precision: 0.7128 - recall: 0.3743 - val_loss: 0.8897 - val_accuracy: 0.5812 - val_precision: 0.8000 - val_recall: 0.3761
# Epoch 16/35
# 12/12 [==============================] - 21s 2s/step - loss: 0.8223 - accuracy: 0.6285 - precision: 0.7137 - recall: 0.4525 - val_loss: 0.9472 - val_accuracy: 0.6068 - val_precision: 0.6774 - val_recall: 0.3590
# Epoch 17/35
# 12/12 [==============================] - 22s 2s/step - loss: 0.7439 - accuracy: 0.6313 - precision: 0.7320 - recall: 0.5112 - val_loss: 0.9257 - val_accuracy: 0.6581 - val_precision: 0.7465 - val_recall: 0.4530
# Epoch 18/35
# 12/12 [==============================] - 19s 2s/step - loss: 0.7212 - accuracy: 0.6536 - precision: 0.7197 - recall: 0.5307 - val_loss: 0.9124 - val_accuracy: 0.6581 - val_precision: 0.7215 - val_recall: 0.4872
# Epoch 19/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.6733 - accuracy: 0.6872 - precision: 0.7481 - recall: 0.5642 - val_loss: 0.9132 - val_accuracy: 0.6410 - val_precision: 0.7568 - val_recall: 0.4786
# Epoch 20/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.7136 - accuracy: 0.6872 - precision: 0.7447 - recall: 0.5866 - val_loss: 0.8702 - val_accuracy: 0.5983 - val_precision: 0.7356 - val_recall: 0.5470
# Epoch 21/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.6856 - accuracy: 0.7011 - precision: 0.7660 - recall: 0.6034 - val_loss: 0.8764 - val_accuracy: 0.6496 - val_precision: 0.7416 - val_recall: 0.5641
# Epoch 22/35
# 12/12 [==============================] - 22s 2s/step - loss: 0.6615 - accuracy: 0.7067 - precision: 0.7885 - recall: 0.6145 - val_loss: 0.8864 - val_accuracy: 0.6325 - val_precision: 0.7253 - val_recall: 0.5641
# Epoch 23/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.6425 - accuracy: 0.7179 - precision: 0.7641 - recall: 0.6425 - val_loss: 0.8763 - val_accuracy: 0.6239 - val_precision: 0.6596 - val_recall: 0.5299
# Epoch 24/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.6229 - accuracy: 0.7207 - precision: 0.7632 - recall: 0.6480 - val_loss: 0.8561 - val_accuracy: 0.6581 - val_precision: 0.7143 - val_recall: 0.5983
# Epoch 25/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.6644 - accuracy: 0.7291 - precision: 0.7687 - recall: 0.6592 - val_loss: 0.9513 - val_accuracy: 0.5726 - val_precision: 0.6000 - val_recall: 0.5128
# Epoch 26/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.6366 - accuracy: 0.7011 - precision: 0.7588 - recall: 0.6592 - val_loss: 0.9625 - val_accuracy: 0.5556 - val_precision: 0.6304 - val_recall: 0.4957
# Epoch 27/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.6450 - accuracy: 0.7123 - precision: 0.7508 - recall: 0.6648 - val_loss: 0.8620 - val_accuracy: 0.6496 - val_precision: 0.6700 - val_recall: 0.5726
# Epoch 28/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.5847 - accuracy: 0.7514 - precision: 0.7690 - recall: 0.6788 - val_loss: 0.7879 - val_accuracy: 0.6838 - val_precision: 0.7071 - val_recall: 0.5983
# Epoch 29/35
# 12/12 [==============================] - 18s 2s/step - loss: 0.6164 - accuracy: 0.7291 - precision: 0.7595 - recall: 0.6704 - val_loss: 0.8174 - val_accuracy: 0.6838 - val_precision: 0.6970 - val_recall: 0.5897
# Epoch 30/35
# 12/12 [==============================] - 22s 2s/step - loss: 0.5775 - accuracy: 0.7626 - precision: 0.7898 - recall: 0.6927 - val_loss: 0.7879 - val_accuracy: 0.6581 - val_precision: 0.7292 - val_recall: 0.5983
# Epoch 31/35
# 12/12 [==============================] - 20s 2s/step - loss: 0.6383 - accuracy: 0.7291 - precision: 0.7752 - recall: 0.6453 - val_loss: 0.8404 - val_accuracy: 0.6410 - val_precision: 0.7234 - val_recall: 0.5812
# Epoch 32/35
# 12/12 [==============================] - 18s 1s/step - loss: 0.5996 - accuracy: 0.7514 - precision: 0.7830 - recall: 0.6955 - val_loss: 0.7713 - val_accuracy: 0.7009 - val_precision: 0.7600 - val_recall: 0.6496
# Epoch 33/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.5397 - accuracy: 0.7458 - precision: 0.7562 - recall: 0.6844 - val_loss: 0.8725 - val_accuracy: 0.6154 - val_precision: 0.6667 - val_recall: 0.5812
# Epoch 34/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.5547 - accuracy: 0.7598 - precision: 0.7815 - recall: 0.7095 - val_loss: 0.7720 - val_accuracy: 0.6667 - val_precision: 0.7048 - val_recall: 0.6325
# Epoch 35/35
# 12/12 [==============================] - 17s 1s/step - loss: 0.5277 - accuracy: 0.7821 - precision: 0.8000 - recall: 0.7263 - val_loss: 0.7696 - val_accuracy: 0.7009 - val_precision: 0.6952 - val_recall: 0.6239

# %%
# Plotting the Graphs for Loss, Accuracy, Precision, Recall
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot();
history_frame.loc[:, ['precision', 'val_precision']].plot();
history_frame.loc[:, ['recall', 'val_recall']].plot();

# %%
model.evaluate(ds_train)
# Out:
# 12/12 [==============================] - 8s 646ms/step - loss: 0.5570 - accuracy: 0.7682 - precision: 0.7818 - recall: 0.7207
# [0.5569994449615479,
#  0.7681564092636108,
#  0.7818182110786438,
#  0.7206704020500183]

# %%
model.evaluate(ds_test)
# Out:
# 121/121 [==============================] - 3s 25ms/step - loss: 1.1510 - accuracy: 0.5868 - precision: 0.6481 - recall: 0.5785
# [1.150961995124817, 0.586776852607727, 0.6481481194496155, 0.5785123705863953]

# %% [markdown]
# Observations:
# - From model evaluation we can see the accuracy for train is 0.76 and test is 0.58
# - So, there clearly seems to be overfitting but it is acceptable as we had only 598 samples which is low for trainning a CNN for image classification.

# %% [markdown]
# Challenges faced in training the model

# %% [markdown]
#  - Tried to load the data directly from the official site but at first there was an url Downloaderror. Had to update the tfds library.
#  - Only Train split was available on the official site, could not get the data like that of Demo.
#  - Also the RGB lists of the image column were not supported for training as they were not in sequence.
#  - Encountered ValueError while training as the model could not convert numpy array to Tensor.

# %% [markdown]
# If your GPU runs out of memory while training a CNN, what are five things you could try to solve the problem?

# %% [markdown]
#  - We use 16 bit floats instead of 32 bit floats
#  - Distributing CNN on multiple devices
#  - Remove one or more layers
#  - Reduce the size of mini-lot
#  - Reduce dimensionality by using a larger stride in one or more layers.

# %% [markdown]
# What are the advantages of a CNN over a fully connected DNN for image classification?

# %% [markdown]
#  - CNN's layers are only partially connnected and reuses its weights.
#  - Learned a kernel which can detect a particular features.
#  - A CNN's architecture embeds knowledge of neighbouring pixels.
#  - Fewer Parameters, Which means faster to train.
